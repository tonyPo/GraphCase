# %%
import sys
from datetime import datetime
from dateutil.relativedelta import relativedelta
from matplotlib import cm
import matplotlib
import matplotlib.pyplot as plt
import pickle
# load the folder with the python file to te PATH variable
sys.path.insert(0, '/dbfs/mnt/dsee-car-d-01/GraphSage/code/GAE')
from sparkSampler_GAE import SparkSampler
from graphAutoEncoder import GraphAutoEncoder
import tensorflow as tf
tf.enable_eager_execution()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
training_folder = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/sample/'
out_dir = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/embedding/'

# for testing
# training_folder = '/dbfs/mnt/dsee-car-d-01/GraphSage/output/test_unit/sample_gae/'
# out_dir = '/dbfs/mnt/dsee-car-d-01/GraphSage/output/test_unit/sample_gae/embedding'

# prep
res = []
graphAutoEncoder = GraphAutoEncoder(training_folder, out_dir, 
                                   dims = [32,32,32,32],
                                   batch_size = 1024,
                                   validate_iter=100,
                                   print_every=100,
                                   batches_per_file = 1000,
                                   max_total_steps = 20000,
                                   embedding_file =  "embedding_v"
                                   )


lrs = [0.00005, 0.0001, 0.0005, 0.001, 0.002]
acts = [tf.nn.sigmoid] # [tf.nn.sigmoid, tf.nn.relu, None]
dims = [35] #[21, 23, 25, 27, 29, 31, 33, 35, 37, 39, 41] #of node label = 49 + 1 edge label
for lr in lrs:
  for act in acts:
    for dim in dims:
      print("dim: ", dim, " act: ", act, " lr: ", lr)
      h = graphAutoEncoder.train_layer(1, dim, lr, act)
      res.append((dim,lr,act,h))

res_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/training_layer1_lr'
pickle.dump(res, open( res_file, "wb"))

# %%
training_folder = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/sample/'
out_dir = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/embedding/'

# prep
res = []
graphAutoEncoder = GraphAutoEncoder(training_folder, out_dir, 
                                   dims = [32,32,32,32],
                                   batch_size = 1024,
                                   validate_iter=100,
                                   print_every=100,
                                   batches_per_file = 1000,
                                   max_total_steps = 20000,
                                   embedding_file =  "embedding_v"
                                   )


lrs = [0.002]
acts = [tf.nn.sigmoid, tf.nn.relu, tf.nn.tanh, "iden"]
dims = [35] #[21, 23, 25, 27, 29, 31, 33, 35, 37, 39, 41] #of node label = 49 + 1 edge label
for lr in lrs:
  for act in acts:
    for dim in dims:
      print("dim: ", dim, " act: ", act, " lr: ", lr)
      h = graphAutoEncoder.train_layer(1, dim, lr, act)
      res.append((dim,lr,act,h))

res_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/training_layer1_act3'
pickle.dump(res, open( res_file, "wb"))

# %%
training_folder = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/sample/'
out_dir = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/embedding/'

# prep
res = []
graphAutoEncoder = GraphAutoEncoder(training_folder, out_dir, 
                                   dims = [32,32,32,32],
                                   batch_size = 1024,
                                   validate_iter=100,
                                   print_every=100,
                                   batches_per_file = 1000,
                                   max_total_steps = 10000,
                                   embedding_file =  "embedding_v"
                                   )


lrs = [0.002]
acts = [tf.nn.sigmoid] #[tf.nn.sigmoid, tf.nn.relu, tf.nn.tanh, "iden"]
dims = [29, 31, 33, 35, 37, 39, 41, 43, 45, 47] #of node label = 55 edge label
for lr in lrs:
  for act in acts:
    for dim in dims:
      print("dim: ", dim, " act: ", act, " lr: ", lr)
      h = graphAutoEncoder.train_layer(1, dim, lr, act)
      res.append((dim,lr,act,h))

res_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/training_layer1_dim'
pickle.dump(res, open( res_file, "wb"))

# %%
training_folder = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/sample/'
out_dir = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/embedding/'

# prep
res = []
graphAutoEncoder = GraphAutoEncoder(training_folder, out_dir, 
                                   dims = [32,32,32,32],
                                   batch_size = 1024,
                                   validate_iter=100,
                                   print_every=100,
                                   batches_per_file = 1000,
                                   max_total_steps = 20000,
                                   embedding_file =  "embedding_v"
                                   )

lrs = [0.002]
acts = [tf.nn.sigmoid] #[tf.nn.sigmoid, tf.nn.relu, tf.nn.tanh, "iden"]
dims = [45] #of node label = 55 edge label
for lr in lrs:
  for act in acts:
    for dim in dims:
      print("dim: ", dim, " act: ", act, " lr: ", lr)
      h = graphAutoEncoder.train_layer(1, dim, lr, act)
      res.append((dim,lr,act,h))

res_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/training_layer1_final'
pickle.dump(res, open( res_file, "wb"))
layer1_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/model/gea_layer1_final'
graphAutoEncoder.model.save_layer(1, layer1_file)

# %%
training_folder = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/sample/'
out_dir = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/embedding/'
layer1_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/model/gea_layer1_final'

# prep
res = []
# graphAutoEncoder = GraphAutoEncoder(training_folder, out_dir, 
#                                    dims = [32,32,32,32],
#                                    batch_size = 1024,
#                                    validate_iter=100,
#                                    print_every=100,
#                                    batches_per_file = 1000,
#                                    max_total_steps = 20000,
#                                    embedding_file =  "embedding_v"
#                                    )
# graphAutoEncoder.model.load_layer(1, layer1_file)

lrs = [0.002]
acts = [tf.nn.sigmoid] #[tf.nn.sigmoid, tf.nn.relu, tf.nn.tanh, "iden"]
#input dimension is 45*21 = 945
dims = [64, 128, 256, 384, 512] #of node label = 55 edge label
for lr in lrs:
  for act in acts:
    for dim in dims:
      print("dim: ", dim, " act: ", act, " lr: ", lr)
      h = graphAutoEncoder.train_layer(2, dim, lr, act)
      res.append((dim,lr,act,h))

res_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/training_layer2_dims'
pickle.dump(res, open( res_file, "wb"))

# %%
training_folder = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/sample/'
out_dir = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/embedding/'
layer1_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/model/gea_layer1_final'

# prep
res = []
graphAutoEncoder = GraphAutoEncoder(training_folder, out_dir, 
                                   dims = [32,32,32,32],
                                   batch_size = 1024,
                                   validate_iter=100,
                                   print_every=100,
                                   batches_per_file = 1000,
                                   max_total_steps = 9000,
                                   embedding_file =  "embedding_v"
                                   )
graphAutoEncoder.model.load_layer(1, layer1_file)

lrs = [0.002]
acts = [tf.nn.sigmoid] #[tf.nn.sigmoid, tf.nn.relu, tf.nn.tanh, "iden"]
#input dimension is 45*21 = 945
dims = [128] #of node label = 55 edge label
for lr in lrs:
  for act in acts:
    for dim in dims:
      print("dim: ", dim, " act: ", act, " lr: ", lr)
      h = graphAutoEncoder.train_layer(2, dim, lr, act)
      res.append((dim,lr,act,h))

res_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/training_layer2_final'
pickle.dump(res, open( res_file, "wb"))
layer2_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/model/gea_layer2_final'
graphAutoEncoder.model.save_layer(2, layer2_file)

# %%
training_folder = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/sample/'
out_dir = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/embedding/'
layer1_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/model/gea_layer1_final'
layer2_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/model/gea_layer2_final'

# prep
res = []
# graphAutoEncoder = GraphAutoEncoder(training_folder, out_dir, 
#                                    dims = [32,32,32,32],
#                                    batch_size = 1024,
#                                    validate_iter=100,
#                                    print_every=100,
#                                    batches_per_file = 1000,
#                                    max_total_steps = 15000,
#                                    embedding_file =  "embedding_v"
#                                    )
# graphAutoEncoder.model.load_layer(1, layer1_file)
# graphAutoEncoder.model.load_layer(2, layer2_file)

lrs = [0.002]
acts = [tf.nn.sigmoid] #[tf.nn.sigmoid, tf.nn.relu, tf.nn.tanh, "iden"]
#input dimension is 45*21 = 945
dims = [32,64, 69]  # [32,64, 69, 128, 160] #of node label = 55 edge label
for lr in lrs:
  for act in acts:
    for dim in dims:
      print("dim: ", dim, " act: ", act, " lr: ", lr)
      h = graphAutoEncoder.train_layer(3, dim, lr, act)
      res.append((dim,lr,act,h))

res_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/training_layer3_dim'
pickle.dump(res, open( res_file, "wb"))

# %%
res_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/training_layer3_dim1'
pickle.dump(res, open( res_file, "wb"))

# %%
training_folder = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/sample/'
out_dir = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/embedding/'
layer1_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/model/gea_layer1_final'
layer2_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/model/gea_layer2_final'

# prep
res = []
graphAutoEncoder = GraphAutoEncoder(training_folder, out_dir, 
                                   dims = [32,32,32,32],
                                   batch_size = 1024,
                                   validate_iter=100,
                                   print_every=100,
                                   batches_per_file = 1000,
                                   max_total_steps = 20000,
                                   embedding_file =  "embedding_v"
                                   )
graphAutoEncoder.model.load_layer(1, layer1_file)
graphAutoEncoder.model.load_layer(2, layer2_file)

lrs = [0.002]
acts = [tf.nn.sigmoid] #[tf.nn.sigmoid, tf.nn.relu, tf.nn.tanh, "iden"]
#input dimension is 45*21 = 945
dims = [128]  # [32,64, 69, 128, 160] #of node label = 55 edge label
for lr in lrs:
  for act in acts:
    for dim in dims:
      print("dim: ", dim, " act: ", act, " lr: ", lr)
      h = graphAutoEncoder.train_layer(3, dim, lr, act)
      res.append((dim,lr,act,h))

res_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/training_layer3_dim'
pickle.dump(res, open( res_file, "wb"))
layer3_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/model/gea_layer3_final'
graphAutoEncoder.model.save_layer(3, layer3_file)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">init graphsage
# initialize data feeder
# loading  node_labels   2019-11-29 10:49:19.691135
# sorting  node_labels  :  2019-11-29 10:58:44.840780
# loading  node_labels  finished  2019-11-29 10:58:47.038044
# loading  in_sample   2019-11-29 10:58:47.095480
# sorting  in_sample  :  2019-11-29 11:03:40.882074
# loading  in_sample  finished  2019-11-29 11:03:43.478304
# loading  out_sample   2019-11-29 11:03:43.504307
# sorting  out_sample  :  2019-11-29 11:08:35.931582
# loading  out_sample  finished  2019-11-29 11:08:38.548057
# loading  in_sample_amnt   2019-11-29 11:08:38.573888
# ...

# %%
training_folder = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/sample/'
out_dir = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/embedding/'
layer1_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/model/gea_layer1_final'
layer2_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/model/gea_layer2_final'
layer3_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/model/gea_layer3_final'
layer4_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/model/gea_layer4'

# prep
res = []
# graphAutoEncoder = GraphAutoEncoder(training_folder, out_dir, 
#                                    dims = [32,32,32,32],
#                                    batch_size = 1024,
#                                    validate_iter=100,
#                                    print_every=100,
#                                    batches_per_file = 1000,
#                                    max_total_steps = 20000,
#                                    embedding_file =  "embedding_v"
#                                    )
# graphAutoEncoder.model.load_layer(1, layer1_file)
# graphAutoEncoder.model.load_layer(2, layer2_file)
# graphAutoEncoder.model.load_layer(3, layer3_file)

lrs = [0.002]
acts = [tf.nn.sigmoid] #[tf.nn.sigmoid, tf.nn.relu, tf.nn.tanh, "iden"]
#input dimension is 45*21 = 945
dims = [32,64]
for lr in lrs:
  for act in acts:
    for dim in dims:
      print("dim: ", dim, " act: ", act, " lr: ", lr)
      h = graphAutoEncoder.train_layer(4, dim, lr, act)
      res.append((dim,lr,act,h))
      graphAutoEncoder.model.save_layer(4, layer4_file + "_dim" + str(dim))
      
res_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/training_layer4_dim'
pickle.dump(res, open( res_file, "wb"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dim:  32  act:  &lt;function sigmoid at 0x7f8f5670c048&gt;  lr:  0.002
# Iter: 0000 train_loss= 97.28465 val_loss= 103.58432 time= 2019-11-29 19:20:05
# Iter: 0100 train_loss= 74.97009 val_loss= 76.62227 time= 2019-11-29 19:22:32
# Iter: 0200 train_loss= 67.55347 val_loss= 70.06324 time= 2019-11-29 19:24:59
# Iter: 0300 train_loss= 74.20532 val_loss= 68.25066 time= 2019-11-29 19:27:26
# Iter: 0400 train_loss= 66.05796 val_loss= 67.68936 time= 2019-11-29 19:29:52
# Iter: 0500 train_loss= 68.23484 val_loss= 66.84149 time= 2019-11-29 19:32:19
# Iter: 0600 train_loss= 61.71426 val_loss= 66.10271 time= 2019-11-29 19:34:46
# ...

# %%
res_file = '/dbfs/mnt/dsee-car-d-01/GraphSage/output_gae/unsup/training_layer4_dim1'
pickle.dump(res, open( res_file, "wb"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
